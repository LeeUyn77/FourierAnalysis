# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n=1024
w=np.exp(-np.imag(1j)*2*np.pi/n)

J,K=np.meshgrid(np.arange(n),np.arange(n))
DFT=np.power(w,J*K)
DFT=np.real(DFT)

plt.imshow(DFT)
plt.show(DFT.all())
