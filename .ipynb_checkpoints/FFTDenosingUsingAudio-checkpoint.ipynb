# %%
write("example.wav", sampleRate, raw.astype(np.int16))
wav1=wa.open('example.wav','r')
noise=wav1.readframes(-1)
noise=np.frombuffer(noise,"int16")
noise_sampleRate=wav1.getframerate()

plt.title('Waveform of Audio File')
plt.plot(time,noise,color='red',label='noisy')
plt.ylabel('Amplitude')
plt.xlabel('Time')
plt.legend()
plt.xlim(0,2)
plt.show()

# %%
import wave as wa
import numpy as np
import matplotlib.pyplot as plt
from scipy.io.wavfile import write
from playsound import playsound

# %%
plt.rcParams['figure.figsize']=[9,6]
plt.rcParams.update({'font.size': 12})

# %%
wav=wa.open('tlam.wav','r')
raw=wav.readframes(-1)
raw=np.frombuffer(raw,"int16")
sampleRate=wav.getframerate()
time=np.linspace(0,len(raw)/sampleRate,num=len(raw))
#raw_clean=raw
#raw with noise
#raw=raw+2.5*np.random.randn(len(time))

# %%
plt.title('Waveform of Audio File')
plt.plot(time,raw,color='red',label='noisy')
plt.ylabel('Amplitude')
plt.xlabel('Time')
plt.legend()
plt.xlim(0,150)
plt.show()

# %%
#compute the fft
n=len(time)
fhat=np.fft.fft(raw,n)
PSD=fhat*np.conj(fhat)/n
freq=(1/(len(raw)/sampleRate))*time
L=np.arange(1,np.floor(n/2),dtype='int')

fig,axs=plt.subplots(2,1)

plt.sca(axs[0])
plt.plot(time,raw,color='red',label='Noisy')
plt.xlim(0,150)
plt.ylim(-30000,30000)
plt.legend()

plt.sca(axs[1])
plt.plot(freq[L],PSD[L],color='red',label='Noisy')
plt.xlim(freq[L[0]],freq[L[-1]])
plt.legend()

plt.show()

# %%
#use the PSD to filter out noise
indices=PSD>25000
PSDclean=PSD*indices
fhat=fhat*indices
ffilt=np.fft.ifft(fhat)

# %%
#plot everything together
fig,axs=plt.subplots(3,1)

plt.sca(axs[0])
plt.plot(time,raw,color='red',label='Noisy')
plt.xlim(0,150)
plt.ylim(-30000,30000)
plt.legend()

plt.sca(axs[2])
plt.plot(time,ffilt,color='pink',label='Filtered')
plt.xlim(0,150)
plt.ylim(-30000,30000)
plt.legend()

plt.sca(axs[1])
plt.plot(freq[L],PSD[L],color='yellow',label='Noisy')
plt.plot(freq[L],PSDclean[L],color='pink',label='Filtered')
plt.xlim(freq[L[0]],freq[L[-1]])
plt.legend()

write("result.wav", sampleRate, ffilt.astype(np.int16))

plt.show()
# Out:
# /var/folders/wf/606tgcgx6rq99xkrjhnpc30m0000gn/T/ipykernel_49739/4128102718.py:21: ComplexWarning: Casting complex values to real discards the imaginary part
#   write("result.wav", sampleRate, ffilt.astype(np.int16))
